# %%
import pandas as pd
d={}
list=['Manish','Raaj','Simran','Rahaul','Kiran']
list2=[1000,4000,3000,4400,5500]
for i,j in zip(list,list2):
    d[i]=j
d1=pd.DataFrame(d.items(),columns=['Name','Sallery'])
d1
# Out:
#      Name  Sallery
# 0  Manish     1000
# 1    Raaj     4000
# 2  Simran     3000
# 3  Rahaul     4400
# 4   Kiran     5500

# %%
list=[11,22,33,44,55]
d1['Numb']=list
d1
# Out:
#      Name  Sallery  Numb
# 0  Manish     1000    11
# 1    Raaj     4000    22
# 2  Simran     3000    33
# 3  Rahaul     4400    44
# 4   Kiran     5500    55

# %%
d=pd.DataFrame({'Name':['SANDY'],'Sallery':2900,'Numb':66})
d1=pd.concat([d1,d],ignore_index=True)
d1
# Out:
#      Name  Sallery  Numb
# 0  Manish     1000    11
# 1    Raaj     4000    22
# 2  Simran     3000    33
# 3  Rahaul     4400    44
# 4   Kiran     5500    55
# 5   SANDY     2900    66

# %%
Num=[num for num in range(10,70,10)]
d1['Numb']=Num
d2=d1
d2
# Out:
#      Name  Sallery  Numb
# 0  Manish     1000    10
# 1    Raaj     4000    20
# 2  Simran     3000    30
# 3  Rahaul     4400    40
# 4   Kiran     5500    50
# 5   SANDY     2900    60

# %%
num=[num**2 for num in range(1,7)]
d2['Square']=num
d2
# Out:
#      Name  Sallery  Numb  Square  Cube
# 0  Manish     1000    10       1     1
# 1    Raaj     4000    20       4     8
# 2  Simran     3000    30       9    27
# 3  Rahaul     4400    40      16    64
# 4   Kiran     5500    50      25   125
# 5   SANDY     2900    60      36   216

# %%
d2['Cube']=Cube=[num**3 for num in range(1,7)]
d2
# Out:
#      Name  Sallery  Numb  Square  Cube
# 0  Manish     1000    10       1     1
# 1    Raaj     4000    20       4     8
# 2  Simran     3000    30       9    27
# 3  Rahaul     4400    40      16    64
# 4   Kiran     5500    50      25   125
# 5   SANDY     2900    60      36   216

# %%
d2['Update']=up=[num**4 for num in range(1,7)]
d2
# Out:
#      Name  Sallery  Numb  Square  Cube  Update
# 0  Manish     1000    10       1     1       1
# 1    Raaj     4000    20       4     8      16
# 2  Simran     3000    30       9    27      81
# 3  Rahaul     4400    40      16    64     256
# 4   Kiran     5500    50      25   125     625
# 5   SANDY     2900    60      36   216    1296

# %%
ww=pd.DataFrame({'Name':'Yuviraj','Sallery':[5555],'Numb':666,'Square':45,'Cube':[52],'Update':777})
df=pd.concat([d2,ww],ignore_index=True)
df
# Out:
#       Name  Sallery  Numb  Square  Cube  Update
# 0   Manish     1000    10       1     1       1
# 1     Raaj     4000    20       4     8      16
# 2   Simran     3000    30       9    27      81
# 3   Rahaul     4400    40      16    64     256
# 4    Kiran     5500    50      25   125     625
# 5    SANDY     2900    60      36   216    1296
# 6  Yuviraj     5555   666      45    52     777

# %%
df.take([:])
# Out:
#   Cell In[111], line 1
#     df.take([:])
#              ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# %%
plt.title('A Bar Graph')
plt.xlabel('Name')
plt.ylabel('Sallery')
plt.bar(d2.Name,d2.Sallery)
plt.show()

# %%
students=['XX','YY','ZZ']
point=[20,50,36]
c=['y','r','b']
plt.pie(point,labels=students,colors=c,shadow=True,
       explode=(0.05,0.05,0.05),autopct='%1.1f%%')
plt.axis('equal')
plt.legend()
plt.show()

# %%
df
# Out:
#       Name  Sallery  Numb  Square  Cube  Update
# 0   Manish     1000    10       1     1       1
# 1     Raaj     4000    20       4     8      16
# 2   Simran     3000    30       9    27      81
# 3   Rahaul     4400    40      16    64     256
# 4    Kiran     5500    50      25   125     625
# 5    SANDY     2900    60      36   216    1296
# 6  Yuviraj     5555   666      45    52     777

# %%
df1=df.dtypes
f={}
for i,j in df1.items():
    f[i]=j
f
# Out:
# {'Name': dtype('O'),
#  'Sallery': dtype('int64'),
#  'Numb': dtype('int64'),
#  'Square': dtype('int64'),
#  'Cube': dtype('int64'),
#  'Update': dtype('int64')}

# %%
name,num=[],[]
for i,j in f.items():
    name.append(i)
    num.append(j)
df_new=pd.DataFrame(zip(name,num),columns=['Name','Num'])
df_new
# Out:
#       Name     Num
# 0     Name  object
# 1  Sallery   int64
# 2     Numb   int64
# 3   Square   int64
# 4     Cube   int64
# 5   Update   int64

# %%
dic={}
list=['m','a','n','i']
list1=[1,2,3,4]
for i,j in zip(list,list1):
    dic[i]=j
pd.DataFrame(dic.items())
# Out:
#    0  1
# 0  m  1
# 1  a  2
# 2  n  3
# 3  i  4

# %%
import numpy as np

# %%
pd.DataFrame(np.arange(10,50,5).reshape(2,4),index=['Row1','Row2'],columns=['Column1','Column2','Column3','Column4'])
# Out:
#       Column1  Column2  Column3  Column4
# Row1       10       15       20       25
# Row2       30       35       40       45

# %%
list=['XX','YY','ZZ','AA','BB','CC','DD']
name=np.array(list)
sallery=[100,200,300,400,500,600,700]
sallery=np.array(sallery)
df_1=pd.DataFrame(zip(name,sallery),columns=['Name','Sallery'])
df_1
# Out:
#   Name  Sallery
# 0   XX      100
# 1   YY      200
# 2   ZZ      300
# 3   AA      400
# 4   BB      500
# 5   CC      600
# 6   DD      700

# %%
df_1['City']=city=['Hyd','Blr','Bpl','JBL','WST','MHH','JHH']
df_1
# Out:
#   Name  Sallery City
# 0   XX      100  Hyd
# 1   YY      200  Blr
# 2   ZZ      300  Bpl
# 3   AA      400  JBL
# 4   BB      500  WST
# 5   CC      600  MHH
# 6   DD      700  JHH

# %%
df_1.iloc[3]='SS',333,'KLN'
df_1
# Out:
#   Name  Sallery City
# 0   XX      100  Hyd
# 1   YY      200  Blr
# 2   ZZ      300  Bpl
# 3   SS      333  KLN
# 4   BB      500  WST
# 5   CC      600  MHH
# 6   DD      700  JHH

# %%
df_1.rename(columns={'City':'City_updated'})
# Out:
#   Name  Sallery City_updated
# 0   XX      100          Hyd
# 1   YY      200          Blr
# 2   ZZ      300          Bpl
# 3   SS      333          KLN
# 4   BB      500          WST
# 5   CC      600          MHH
# 6   DD      700          JHH

# %%
df_1.rename(columns={'Sallery':'SALLERY'})
# Out:
#   Name  SALLERY City
# 0   XX      100  Hyd
# 1   YY      200  Blr
# 2   ZZ      300  Bpl
# 3   SS      333  KLN
# 4   BB      500  WST
# 5   CC      600  MHH
# 6   DD      700  JHH

# %%
p='manish@gmail.com'
l=p.find('@')
m=p.find('.')
print(p[l+1:m])
# Out:
# gmail
